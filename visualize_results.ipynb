# %%
import os
import time
import logging
from datetime import datetime
from collections import defaultdict
import numpy as np
import torch

from fcr import FCR_sim
from fcr.evaluate.evaluate import evaluate, evaluate_classic, evaluate_prediction
from fcr.dataset.dataset import load_dataset_splits, load_dataset_train_test
from fcr.utils.general_utils import initialize_logger, ljson
from fcr.utils.data_utils import data_collate
from fcr.dataset.dataset import load_dataset_splits, load_dataset_train_test

# %% [markdown]
# ## Load the model and datasets

# %%
model_path = "/cluster/work/bewi/members/rquiles/experiments/test_3cell_lines/model/saves/test_run_2025.10.01_14:56:03/model_seed=None_epoch=180.pt"
fcr_model = FCR_sim(model_path=model_path, dataset_mode="all")

trained_model = fcr_model.model
datasets = fcr_model.dataset
args = fcr_model.arguments
# Out:
# Performing automatic train-test split with 0.2 ratio.

# %% [markdown]
# ## Load Representations

# %%
import numpy as np
from tqdm import tqdm

ZXs = []
ZTs = []
ZXTs = []
for data in tqdm(datasets["loader_tr"], desc="Processing batches"):
    (genes, perts, cf_genes, cf_perts, covariates) = (
            data[0], data[1], data[2], data[3], data[4:])

    ZX, ZXT, ZT = trained_model.get_latent_presentation(genes, perts, covariates, sample=False) # sigma1=2e-1, sigma2=5e-3, sigma3=1e-3)
    ZXs.extend(ZX)
    ZTs.extend(ZT)
    ZXTs.extend(ZXT)
# Out:
# Processing batches: 100%|██████████| 973/973 [04:17<00:00,  3.78it/s]

# %%
ZXs = [e.detach().cpu().numpy() for e in ZXs]
ZXs = np.array(ZXs)

ZXTs = [e.detach().cpu().numpy() for e in ZXTs]
ZXTs = np.array(ZXTs)

ZTs = [e.detach().cpu().numpy() for e in ZTs]
ZTs = np.array(ZTs)

# %% [markdown]
# ## Load the RAW data to ADATA

# %%
import scanpy as sc
adata = sc.read(args["data_path"])

# %%
adata.obsm["ZXs"] = ZXs
adata.obsm["ZTs"] = ZTs
adata.obsm["ZXTs"] = ZXTs

# %% [markdown]
# ## Plot the Zx

# %%
sc.pp.neighbors(adata, use_rep="ZXs")
sc.tl.umap(adata, min_dist=0.3)
adata.obs["covariates"] = adata.obs["covariates"].astype(str)
# adata.obs["cell_type"] = adata.obs["cell_type"].astype(str)
# adata.obs["dose"] = adata.obs["dose"].astype(str)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# def combine_cov(row):
#     celltypes = row["cell_type"]
#     replicate = row["replicate"]
#     return celltypes+'_'+replicate

# adata.obs["covariate"] = adata.obs.apply(combine_cov, axis=1)

# %%
sc.set_figure_params(dpi=80, dpi_save=600, format='png')

# %%
sc.pl.umap(
    adata,
    color=["covariates", "dose"],
    frameon=False,
    palette = "Set2",
    size = 30,
    outline_color= "gray",
    outline_width = 30,
    color_map = 'Blues',
    vcenter=0.01,

)

# %% [markdown]
# ## Plot The Ztx

# %%
sc.pp.neighbors(adata, use_rep="ZXTs")
sc.tl.umap(adata,min_dist=0.5)

# %%
import seaborn as sns

umap_kwargs = dict(
    add_outline=True, outline_width=(0.05,0), outline_color=('grey', 'white'))
sc.pl.umap(
        adata,
        color=["covariates", "dose"],
        frameon=True,
        palette = sns.color_palette('Set3'),
        size = 50,
        color_map = 'Blues',
        vcenter=0.01,**umap_kwargs)

# %% [markdown]
# ## Plot Zt

# %%
sc.pp.neighbors(adata, use_rep="ZTs")

# %%
sc.tl.umap(adata, min_dist=0.5)

# %%
sc.pl.umap(
    adata,
    color=["covariates"],
    frameon=False)

# %%
sc.pl.umap(
    adata,
    color=["Agg_Treatment"],
    # vcenter=0.01,
    frameon=False)

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# ## Clustering Results

# %%
## Leiden clustering with latent representations
sc.pp.neighbors(adata, use_rep="ZXs")
sc.tl.leiden(adata)

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score as nmi
from sklearn.metrics import adjusted_rand_score as ari

# %%
def change_cov_pert(row):
    cov_pert = row["cov_pert_name"].split("_")
    treatment = row["Agg_Treatment"]
    dose = row["dose"]
    cov_pert[-1] = treatment
    cov_pert.append(str(dose))
    return "_".join(cov_pert)

change_cov_pert(adata.obs.iloc[1])
# Out:
# 'MCF7_rep2_HDAC_1.0'

# %%
adata.obs.cov_pert_name = adata.obs.apply(lambda row: change_cov_pert(row), axis=1)

# %% [markdown]
# ## ZX clustering results

# %%
nmivalue = nmi(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
# Out:
# 0.8863428628937162

# %%
arivalue = ari(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.8238444574513598

# %%
nmivalue = nmi(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
# Out:
# 0.09829543937340746

# %%
arivalue = ari(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.05301747408077814

# %%
nmivalue = nmi(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.6511332989518566
# 0.31726414919247337

# %% [markdown]
# ## ZT clustering results

# %%
sc.pp.neighbors(adata, use_rep="ZTs")
sc.tl.leiden(adata)

# %%
nmivalue = nmi(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.5619585830678413
# 0.1395229654570747

# %%
nmivalue = nmi(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.27583042876320196
# 0.06860050247808464

# %%
nmivalue = nmi(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.646582288990604
# 0.29361767026155716

# %% [markdown]
# ## ZXT clustering results

# %%
sc.pp.neighbors(adata, use_rep="ZXTs")
sc.tl.leiden(adata)

# %%
nmivalue = nmi(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.covariate.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.7923130132865274
# 0.5441595967472919

# %%
nmivalue = nmi(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.dose.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.2253500405576085
# 0.0880559105845019

# %%
nmivalue = nmi(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(nmivalue)
arivalue = ari(adata.obs.cov_pert_name.to_numpy(), adata.obs.leiden.to_numpy())
print(arivalue)
# Out:
# 0.7177526301183345
# 0.3721521537956975
